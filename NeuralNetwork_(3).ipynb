# %% [markdown]
# <a href="https://colab.research.google.com/github/INSVikrant54/Neural-Network/blob/main/NeuralNetwork_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# getting output for 3 neuron using dot product (and each set of weights represnt a neuron)

# %%
import numpy as np

inputs = [1, 2, 3, 2.5]
weights = [[0.2 , 0.8 , -0.5 , 1.0],   #weights of 4 diff neuron going to a new single neuron
           [0.5 , -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]

biases = [2, 3, 0.5]

#output = np.dot(inputs,weights) + biases
#need to write weight first or we get shape error in below dot product function
output = np.dot(weights, inputs) + biases
print(output)
# Out:
# [4.8   1.21  2.385]

# %% [markdown]
# getting output for a neuron using dot product

# %%
import numpy as np

inputs = [1, 2, 3, 2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2

output = np.dot(weights, inputs) + bias
print(output)
# Out:
# 4.8

# %% [markdown]
# what bias and weights affects?

# %%
nputs= [1, 2, 3, 2.5]

some_value = 0  # input of given neuron
weight = 0.7
bias = 0.7

print(some_value * weight) # weight just chaing the magnitude
print(some_value + bias)  # bias - offsets the value of thr input
  #bias also states that in activation functionn the neuron is working or not
# Out:
# 0.0
# 0.7

# %% [markdown]
# Tensor is a Object that can be Represented as an Array

# %%
inputs= [1, 2, 3, 2.5]

weights = [[0.2 , 0.8 , -0.5 , 1.0],   #weights of 4 diff neuron going to a new single neuron
           [0.5 , -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]

biases = [2, 3, 0.5]  #bias for each new neuron

layer_outputs = []   # Output of current layer
for neuron_weights, neuron_bias in zip(weights, biases):
  neuron_output = 0  # Output of given neuron
  for n_input, weight in zip(inputs, neuron_weights):
    neuron_output += n_input * weight
  neuron_output += neuron_bias
  layer_outputs.append(neuron_output)

print(layer_outputs)
# Out:
# [4.8, 1.21, 2.385]
