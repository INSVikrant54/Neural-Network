# %% [markdown]
# <a href="https://colab.research.google.com/github/INSVikrant54/Neural-Network/blob/main/NeuronNetwork(1_%26_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Here, we have past 4 Neurons and we are creating data for new 3 neuron

# %%
inputs= [1, 2, 3, 2.5]

weights1 = [0.2 , 0.8 , -0.5 , 1.0]  #weights of 4 diff neuron going to a new single neuron
weights2 = [0.5 , -0.91, 0.26, -0.5]
weights3 = [-0.26, -0.27, 0.17, 0.87]

bias1 = 2 #bias for each new neuron
bias2 = 3
bias3 = 0.5

output = [inputs[0]*weights1[0] + inputs[1]*weights1[1] + inputs[2]*weights1[2] + inputs[3]*weights1[3]+ bias1,
          inputs[0]*weights2[0] + inputs[1]*weights2[1] + inputs[2]*weights2[2] + inputs[3]*weights2[3]+ bias2,
          inputs[0]*weights3[0] + inputs[1]*weights3[1] + inputs[2]*weights3[2] + inputs[3]*weights3[3]+ bias3]
print(output)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# 3 past neuron are feeding into 1 new neuron

# %%
inputs = [1.2 , 5.1 , 2.1]
weights = [3.1 , 2.1 , 8.7]
bias = 3

output = inputs[0]*weights[0] + inputs[1]*weights[1] + inputs[2]*weights[2] + bias
print(output)
# Out:
# 35.7
